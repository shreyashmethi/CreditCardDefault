# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("UCI_Credit_Card.csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as m

# %%
df.hist(bins=50,figsize=(50,50))
m.show()

# %%
import sklearn

# %%
X = df.drop(columns='default.payment.next.month')
y = df.loc[: , 'default.payment.next.month']
X.shape, y.shape
# Out:
# ((30000, 24), (30000,))

# %%
from sklearn.model_selection import train_test_split as tts

# %%
corr_matrix = df.corr()
corr_matrix['default.payment.next.month'].sort_values(ascending=False)
# Out:
# default.payment.next.month    1.000000
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# EDUCATION                     0.028006
# AGE                           0.013890
# BILL_AMT6                    -0.005372
# BILL_AMT5                    -0.006760
# BILL_AMT4                    -0.010156
# ID                           -0.013952
# BILL_AMT3                    -0.014076
# BILL_AMT2                    -0.014193
# BILL_AMT1                    -0.019644
# MARRIAGE                     -0.024339
# SEX                          -0.039961
# PAY_AMT6                     -0.053183
# PAY_AMT5                     -0.055124
# PAY_AMT3                     -0.056250
# PAY_AMT4                     -0.056827
# PAY_AMT2                     -0.058579
# PAY_AMT1                     -0.072929
# ...

# %%
X_train, X_test, y_train, y_test = tts(X,y,test_size=0.2)

# %%
X_train, X_test
# Out:
# (          ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
#  18671  18672    30000.0    2          3         1   22     -2     -2     -2
#  360      361   500000.0    2          2         2   23      4      3      2
#  25006  25007    30000.0    1          3         2   50      2      2      0
#  4787    4788   390000.0    2          1         2   28      0      0      0
#  18988  18989   100000.0    2          1         2   30      3      3      2
#  ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
#  16667  16668    20000.0    1          2         1   32      1      2      2
#  15455  15456    20000.0    1          2         2   24      1      2      0
#  25227  25228    90000.0    2          1         2   24      0      0      0
#  10911  10912    30000.0    2          2         2   22     -1      0     -1
#  24126  24127    80000.0    1          2         2   27      2      2      0
#
# ...

# %%
atr = ['PAY_0', 'PAY_2','PAY_AMT1', 'LIMIT_BAL']

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(X_train[atr], figsize = (20,20))
# Out:
# array([[<AxesSubplot: xlabel='PAY_0', ylabel='PAY_0'>,
#         <AxesSubplot: xlabel='PAY_2', ylabel='PAY_0'>,
#         <AxesSubplot: xlabel='PAY_AMT1', ylabel='PAY_0'>,
#         <AxesSubplot: xlabel='LIMIT_BAL', ylabel='PAY_0'>],
#        [<AxesSubplot: xlabel='PAY_0', ylabel='PAY_2'>,
#         <AxesSubplot: xlabel='PAY_2', ylabel='PAY_2'>,
#         <AxesSubplot: xlabel='PAY_AMT1', ylabel='PAY_2'>,
#         <AxesSubplot: xlabel='LIMIT_BAL', ylabel='PAY_2'>],
#        [<AxesSubplot: xlabel='PAY_0', ylabel='PAY_AMT1'>,
#         <AxesSubplot: xlabel='PAY_2', ylabel='PAY_AMT1'>,
#         <AxesSubplot: xlabel='PAY_AMT1', ylabel='PAY_AMT1'>,
#         <AxesSubplot: xlabel='LIMIT_BAL', ylabel='PAY_AMT1'>],
#        [<AxesSubplot: xlabel='PAY_0', ylabel='LIMIT_BAL'>,
#         <AxesSubplot: xlabel='PAY_2', ylabel='LIMIT_BAL'>,
#         <AxesSubplot: xlabel='PAY_AMT1', ylabel='LIMIT_BAL'>,
#         <AxesSubplot: xlabel='LIMIT_BAL', ylabel='LIMIT_BAL'>]],
#       dtype=object)

# %%
X_train.drop(columns = ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','ID'], inplace = True)

# %%
X_test.drop(columns = ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','ID'], inplace = True)

# %%
X_train.shape
# Out:
# (24000, 17)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
y_train = np.array(y_train)
y_train
# Out:
# array([0, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgdclf=SGDClassifier()

# %%
sgdclf.fit(X_train, y_train.ravel())
# Out:
# SGDClassifier()

# %%
np.array(y_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
pred = sgdclf.predict(X_test)

# %%
sgdclf.score(X_test,y_test)
# Out:
# 0.8031666666666667

# %%
pred = pd.DataFrame(pred)
pred.describe()
# Out:
#                  0
# count  6000.000000
# mean      0.034167
# std       0.181672
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
log_reg.score(X_test,y_test)
# Out:
# 0.8255

# %%
from sklearn.svm import LinearSVC

# %%
svc = LinearSVC()

# %%
svc.fit(X_train , y_train)
# Out:
# C:\Users\Shreyash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
svc.score(X_test, y_test)
# Out:
# 0.8163333333333334

# %%
from sklearn.svm import SVC
poly_svc = SVC(kernel='poly' , degree = 3 , coef0= 1 , C= 5)

# %%
poly_svc.fit(X_train,y_train)
# Out:
# SVC(C=5, coef0=1, kernel='poly')

# %%
poly_svc.score(X_test , y_test)
# Out:
# 0.8253333333333334
